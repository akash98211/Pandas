# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # groupby

# %%
movies_df = pd.read_csv("movies_data.csv")
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_df['content_rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
movies_df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies_df.groupby('genre').first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
movies_df.groupby('genre').get_group('Action')
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
movies_df.groupby('genre').get_group('Crime')
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df_comedy = movies_df.groupby('genre').get_group('Comedy')

# %%
df_comedy.reset_index(drop = True,inplace=True)

# %%
# df_comedy.to_csv('Comedy_Movies.csv')

# %%
df_comedy = movies_df.groupby(['genre','content_rating']).get_group(('Comedy','PG-13'))
df_comedy.shape
# Out:
# (23, 6)

# %%
df_comedy = movies_df.groupby(['genre','content_rating']).get_group(('Comedy','PG-13'))
df_comedy.shape
# Out:
# (23, 6)

# %%
df_comedy
# Out:
#      star_rating                                           title  \
# 25           8.6                               Life Is Beautiful
# 60           8.5                                        3 Idiots
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 459          7.9                        Ferris Bueller's Day Off
# 542          7.8                            (500) Days of Summer
# 578          7.8                              As Good as It Gets
# 622          7.7                                 The Dinner Game
# 639          7.7                                    Billy Elliot
# 667          7.7                               Midnight in Paris
# 696          7.7                           Stranger Than Fiction
# 735          7.6  The Naked Gun: From the Files of Police Squad!
# ...

# %%
df_comedy = movies_df.groupby(['genre','content_rating','duration']).get_group(('Comedy','PG-13',110))
# df_comedy.shape
df_comedy
# Out:
#      star_rating         title content_rating   genre  duration  \
# 639          7.7  Billy Elliot          PG-13  Comedy       110
#
#                                            actors_list
# 639  [u'Jamie Bell', u'Julie Walters', u'Jean Heywo...

# %%
movies_df.groupby('genre').get_group('Family')
# Out:
#      star_rating                                title content_rating   genre  \
# 468          7.9           E.T. the Extra-Terrestrial             PG  Family
# 497          7.8  Willy Wonka & the Chocolate Factory              G  Family
#
#      duration                                        actors_list
# 468       115  [u'Henry Thomas', u'Drew Barrymore', u'Peter C...
# 497       100  [u'Gene Wilder', u'Jack Albertson', u'Peter Os...

# %%
movies_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies_df.loc[1:5]
# Out:
#    star_rating                   title content_rating   genre  duration  \
# 1          9.2           The Godfather              R   Crime       175
# 2          9.1  The Godfather: Part II              R   Crime       200
# 3          9.0         The Dark Knight          PG-13  Action       152
# 4          8.9            Pulp Fiction              R   Crime       154
# 5          8.9            12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
movies_df.loc[movies_df['genre'] == 'Crime']
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_df.loc[(movies_df['genre'] == 'Crime') & (movies_df['content_rating'] == 'R')]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
movies_df.loc[(movies_df['genre'] == 'Comedy') & (movies_df['content_rating'] == 'PG-13')]
# Out:
#      star_rating                                           title  \
# 25           8.6                               Life Is Beautiful
# 60           8.5                                        3 Idiots
# 314          8.0                         Crimes and Misdemeanors
# 356          8.0                                      The Artist
# 370          8.0                          Hannah and Her Sisters
# 459          7.9                        Ferris Bueller's Day Off
# 542          7.8                            (500) Days of Summer
# 578          7.8                              As Good as It Gets
# 622          7.7                                 The Dinner Game
# 639          7.7                                    Billy Elliot
# 667          7.7                               Midnight in Paris
# 696          7.7                           Stranger Than Fiction
# 735          7.6  The Naked Gun: From the Files of Police Squad!
# ...

# %%
movies_df.loc[(movies_df['genre'] == 'Comedy') & (movies_df['content_rating'] == 'PG-13')
             & (movies_df['duration'] >= 120)]
# Out:
#      star_rating               title content_rating   genre  duration  \
# 60           8.5            3 Idiots          PG-13  Comedy       170
# 578          7.8  As Good as It Gets          PG-13  Comedy       139
# 857          7.5       Pleasantville          PG-13  Comedy       124
#
#                                            actors_list
# 60         [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 578  [u'Jack Nicholson', u'Helen Hunt', u'Greg Kinn...
# 857  [u'Tobey Maguire', u'Jeff Daniels', u'Joan All...

# %%
movies_df.loc[(movies_df['duration'] >= 120)
             & (movies_df['duration'] <= 180)]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 6            8.9                   The Good, the Bad and the Ugly
# ..           ...                                              ...
# 967          7.4                                         The Rock
# 968          7.4                              The English Patient
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating    genre  duration  \
# 0                R    Crime       142
# 1                R    Crime       175
# 3            PG-13   Action       152
# ...

# %%
movies_df.loc[(movies_df['duration'] >= 180)]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 17           8.7                                  Seven Samurai
# 40           8.5                                 The Green Mile
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 89           8.4                                         Swades
# 93           8.4                    Dilwale Dulhania Le Jayenge
# 109          8.3                                 Dil Chahta Hai
# 132          8.3                          Judgment at Nuremberg
# 142          8.3              Lagaan: Once Upon a Time in India
# 143          8.2                        The Wolf of Wall Street
# 157          8.2                             Gone with the Wind
# ...

# %%
movies_df.loc[(movies_df['genre'] == 'Action') |
             (movies_df['genre'] == 'Comedy')]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 971          7.4                               Death at a Funeral
# 974          7.4                                          Tootsie
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
movies_df['content_rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
df1 = movies_df.loc[((movies_df['content_rating'] == 'APPROVED') &
             (movies_df['genre'] == 'Comedy')) 
             | (movies_df['star_rating'] >= 9)]

# %%
df1.reset_index(drop=True)
# Out:
#     star_rating                     title content_rating   genre  duration  \
# 0           9.3  The Shawshank Redemption              R   Crime       142
# 1           9.2             The Godfather              R   Crime       175
# 2           9.1    The Godfather: Part II              R   Crime       200
# 3           9.0           The Dark Knight          PG-13  Action       152
# 4           8.5        The Great Dictator       APPROVED  Comedy       125
# 5           8.4       Singin' in the Rain       APPROVED  Comedy       103
# 6           8.3             The Apartment       APPROVED  Comedy       125
# 7           8.1          Bringing Up Baby       APPROVED  Comedy       102
# 8           8.1           His Girl Friday       APPROVED  Comedy        92
# 9           8.0              The Graduate       APPROVED  Comedy       106
# 10          7.9    Miracle on 34th Street       APPROVED  Comedy        96
# ...
