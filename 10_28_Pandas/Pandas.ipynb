# %% [markdown]
# # Pandas

# %% [raw]
# Pandas >> Python Data Analysis

# %% [raw]
# Two Data Structure:
#     1. DataFrame(2-D Data)
#     2. Series(1-D)
#
# 1. DataFrame:
#     1. 2 Dimensional data
#     2. Table with rows and column
#     3. Mutable (Add, Update, Delete)
#
# Use Case:
#     1. Used for working with data sets
#     2. Analysis
#     3. Cleaning
#     4. Manipulating data
#     5. Joining multiple csv/excel(tables)
#     6. Can clean messy data
#     7. Correlations

# %% [markdown]
# # How to Create dataframe

# %%
1. CSV File
2. Excel
3. JSON
4. DataBase(MongoDB, SQLite)

1. List
2. numpy array
3. Dictionary

# %%
import pandas as pd
import numpy as np

# %%
data = {'Column A':[3,4,5,7],'Column B':[10,20,50,30]}
df = pd.DataFrame(data)
# print(df)
df
# Out:
#    Column A  Column B
# 0         3        10
# 1         4        20
# 2         5        50
# 3         7        30

# %% [markdown]
# #### Empty DataFrame

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Column C'] = [90,200,400,100]
df
# Out:
#    Column A  Column B  Column C
# 0         3        10        90
# 1         4        20       200
# 2         5        50       400
# 3         7        30       100

# %%
df['Column D'] = np.array([90,200,400,400])
df
# Out:
#    Column A  Column B  Column D
# 0         3        10        90
# 1         4        20       200
# 2         5        50       400
# 3         7        30       400

# %% [markdown]
# # Read CSV File

# %%
df = pd.read_csv('Iris.csv')
df = pd.read_excel()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#         'Species'],
#        dtype='object')]

# %%
df.shape # to get row_count and Column Count
df.shape[0] # Number of Rows
# Out:
# 150

# %%
df.shape[1]  # Number of Column
# Out:
# 6

# %%
df.describe() # Return stats of all numerical column
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df = pd.read_csv('Iris.csv')
# df = df.T # Transpose of dataframe
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head() # Return first 5 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10) # Return first 5 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.head(7) # Return first 20 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
df.tail()  # Last 5 rows
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail(8)  # Last 8 rows
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# # Access Data From Dataframe

# %% [markdown]
# # 1. slicing

# %%
df[0:5] # df.head()  # Accesing rows only
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df[['SepalLengthCm','PetalLengthCm']]   # Access Columns
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
df[['PetalLengthCm']]  # DataFrame
# Out:
#      PetalLengthCm
# 0              1.4
# 1              1.4
# 2              1.3
# 3              1.5
# 4              1.4
# ..             ...
# 145            5.2
# 146            5.0
# 147            5.2
# 148            5.4
# 149            5.1
#
# [150 rows x 1 columns]

# %%
df['PetalLengthCm']  # DataFrame
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
type(df[['PetalLengthCm']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['PetalLengthCm'])
# Out:
# pandas.core.series.Series

# %%
df[10:18]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa

# %%
df[10:11]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa

# %%
# df[10] # Column

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # 2. loc function

# %%
df = pd.read_csv('Iris.csv',index_col='Id')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.loc[2:5] # 2,3,4,5
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df[2:5] # 2 , 3, 4
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[2:5,'SepalLengthCm']
# Out:
# Id
# 2    4.9
# 3    4.7
# 4    4.6
# 5    5.0
# Name: SepalLengthCm, dtype: float64

# %%
df.loc[2:5,['SepalLengthCm','SepalWidthCm']]
# Out:
#     SepalLengthCm  SepalWidthCm
# Id
# 2             4.9           3.0
# 3             4.7           3.2
# 4             4.6           3.1
# 5             5.0           3.6

# %%
df = pd.read_csv('Iris.csv')
df.head(8)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %%
df[2:5] # 2,3,4
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[2:5,['PetalLengthCm','SepalWidthCm']] # 2,3,4,5
# Out:
#    PetalLengthCm  SepalWidthCm
# 2            1.3           3.2
# 3            1.5           3.1
# 4            1.4           3.6
# 5            1.7           3.9

# %%
df.loc[2:5,"Id":'PetalLengthCm'] # 2,3,4,5
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4
# 5   6            5.4           3.9            1.7

# %%
df.loc[2,"Id":'PetalLengthCm'] # 2,3,4,5
# Out:
# Id                 3
# SepalLengthCm    4.7
# SepalWidthCm     3.2
# PetalLengthCm    1.3
# Name: 2, dtype: object

# %%
# df1 = 2:5
# df2 = 10:15

# %% [markdown]
# # iloc

# %%
df.iloc[rows,columns]

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.iloc[3:6] # 3,4,5
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.loc[3:6] # 3,4,5,6
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
df.iloc[2,3]
# Out:
# 1.3

# %%
df.iloc[5,4]
# Out:
# 0.4

# %%
df.iloc[:,:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iloc[2:5,3:5]
# Out:
#    PetalLengthCm  PetalWidthCm
# 2            1.3           0.2
# 3            1.5           0.2
# 4            1.4           0.2

# %%
df.iloc[2:5,3:5]
# Out:
#    PetalLengthCm  PetalWidthCm
# 2            1.3           0.2
# 3            1.5           0.2
# 4            1.4           0.2

# %%
df.iloc[2:5,-3:]
# Out:
#    PetalLengthCm  PetalWidthCm      Species
# 2            1.3           0.2  Iris-setosa
# 3            1.5           0.2  Iris-setosa
# 4            1.4           0.2  Iris-setosa

# %%
df.iloc[2:10,:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 2   3            4.7           3.2
# 3   4            4.6           3.1
# 4   5            5.0           3.6
# 5   6            5.4           3.9
# 6   7            4.6           3.4
# 7   8            5.0           3.4
# 8   9            4.4           2.9
# 9  10            4.9           3.1

# %%
df.iloc[1,1] = 10000
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2        10000.0           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Create CSV file

# %%
df = df.iloc[:15,1:4]
df
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0             5.1           3.5            1.4
# 1             4.9           3.0            1.4
# 2             4.7           3.2            1.3
# 3             4.6           3.1            1.5
# 4             5.0           3.6            1.4
# 5             5.4           3.9            1.7
# 6             4.6           3.4            1.4
# 7             5.0           3.4            1.5
# 8             4.4           2.9            1.4
# 9             4.9           3.1            1.5
# 10            5.4           3.7            1.5
# 11            4.8           3.4            1.6
# 12            4.8           3.0            1.4
# 13            4.3           3.0            1.1
# 14            5.8           4.0            1.2

# %%
df.to_csv('Test.csv',index = False)

# %%
array = np.random.randint(10,200,size = (5,4))
# array = array.reshape(5,4)
array
# Out:
# array([[ 66,  99,  57, 172],
#        [ 57, 159, 135, 160],
#        [ 90, 156,  59,  64],
#        [ 78,  46,  72, 189],
#        [ 78,  21, 186,  17]])

# %%
df = pd.DataFrame(array,columns= ['A',"B",'C','D'])
df
# Out:
#     A    B    C    D
# 0  66   99   57  172
# 1  57  159  135  160
# 2  90  156   59   64
# 3  78   46   72  189
# 4  78   21  186   17

# %%
df.iloc[1,1] = np.nan
df
# Out:
#     A      B    C    D
# 0  66   99.0   57  172
# 1  57    NaN  135  160
# 2  90  156.0   59   64
# 3  78   46.0   72  189
# 4  78   21.0  186   17

# %%
df['B'].fillna(df['B'].median(),inplace = True)
df
# Out:
#     A      B    C    D
# 0  66   99.0   57  172
# 1  57   72.5  135  160
# 2  90  156.0   59   64
# 3  78   46.0   72  189
# 4  78   21.0  186   17

# %%
# df.hist
# df.boxplot

# %%
df = pd.DataFrame(array,columns= list('abcd'))
df
# Out:
#     a    b    c    d
# 0  66   99   57  172
# 1  57  159  135  160
# 2  90  156   59   64
# 3  78   46   72  189
# 4  78   21  186   17

# %%
df = pd.DataFrame(array,columns= list('abcd'),index = list('asdfg'))
df
# Out:
#     a    b    c    d
# a  66   99   57  172
# s  57  159  135  160
# d  90  156   59   64
# f  78   46   72  189
# g  78   21  186   17

# %%
df.loc['s':'f',['a','b','d']]
# Out:
#     a    b    d
# s  57  159  160
# d  90  156   64
# f  78   46  189

# %%
df.iloc[1:4]
# Out:
#     a    b    c    d
# s  57  159  135  160
# d  90  156   59   64
# f  78   46   72  189
